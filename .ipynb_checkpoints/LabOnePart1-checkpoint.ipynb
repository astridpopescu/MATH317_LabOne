# %% [markdown]
# The naivelog and mylog algorithms are both used to approximate the value of the natrual logarithm of x.
#
# naivelog: given an input x to the function, it first reduces the argument by computing the sqare root n times. In this case the value of n is 15. This means that the value of y (which originally is set to x) approaches 1 as each time you take the square root, the value become closer and closer to one but never exactly one. Once the sqare root is taken n times in order to reduce the argument close to 1, it subtracts 1 from the value of the reduced argument (y) and saves it in l. Finally, the alogorithm takes the value of l (which is reduced argument minus 1) and multiplies is by 2 n times. It then returns the value of l as an approximation for the natrual log of x. The overall idea of this algorithm is to implement ln(x) by changing the value of the argument to ln(x) = 2^n ln(1 + z) where z = nth root(x) - 1. It then uses the first term of the taylor series (which is just z) for ln(1+z) to calculate the value of ln(1+z). The multiplication by 2^n at the end simply scales it back to ln(x) as we had originally taken the square root n times. The value of n is very important in this case as the greater n, the more accurate the approximation. This is since if we reduce z to be as close as possible to 1, the truncation of terms 2 and on in the taylor series will be smaller and less impactful since powers of z will be smaller for low values of z. When x is between 0 and 1, the square root operations will still bring y very close to 1 however it will be less than one. When 1 is subtracted to get l, this will result in a negaive value that will then be scaled by two n times. The final result will in fact be negative which is expected for the natrual logarithm of numbers between 0 an 1.
#
# mylog: given an input x, the algorithm starts by scaling the value of x to x-1 and saving it in z. Then it enters a loop that iterates n times, where;
#     1. it calculates the square root of 1 + z using math library
#     2. adds the result of root(1+z) to 1 to get the denominator of the fraction
#     3. Divides the current value of z by the denominator and sets z to the result of the division
# Next, the algorithm saves the value of z into l and then proceeeds to multiply l by 2 iteratively n times in order to scale the value and approximate the natrual logarithm. Once scaled by two n times, the final value of l is returned. The idea of this algorithm is to scale the argument of ln(1 + x) using the formula ln(1 + x) = 2 ln (1 + z) where z = x/(1 + root(1 + x)). 1 is subtracted first to get ln(x) = ln (1 + x') where x' = x - 1. Then the formula is applied n times in order to get the value of z as close as possible to 0. Afterwards the first term of the taylor series for ln(1 + z) is used in order to approximate ln(1+z) and then by myltiplying by 2 n times, we scale is back to the value of ln(x) which is what was wanted originally. Again, the value of n is very important as the larger it is, the closer the value of z is too zero which means that the smaller the error will be due to the truncation of the 2nd term and so on in the taylor series approximation. When the input x is between 0 and 1, the original computation of x-1 brings the value of z to be negative. The iterative computation on z then approaches zero for the value of ln(1+z) but in this case being less than zero. When we scale back by 2^n, the approximation of ln(x) stays negative which is expected for values between 0 and 1.

# %%
import math

# Instead of having n=15 made it a parameter so that its easier to test for different values of n
def naivelog(x, n):
  y = x
  for i in range(n):
    y = math.sqrt(y)
  l = y-1
  print(l)
  for i in range(n):
    l = l*2
  return l

def mylog(x, n):
    z = x-1
    for i in range(n):
        z = z/(1+math.sqrt(1+z))
    l = z
    print(l)
    for i in range(n):
        l = l*2
    return l

# Here we compute the value of lnx for x = 1 to 14 using naivelog. In each iteration of x
# we also compute the naivelog for increasing values of n to show how n affects the error
print("NAIVELOG")
#loops over values of x
for i in range(1,15):
    print("")
    #loop over values of n
    for j in range(0, 5):
        nlog = naivelog(i, (j+3)*5)
        if math.log(i) == 0:
            print("x: " + str(i) + " n: " + str((j+3)*5) + " naivelog(x): " + str(nlog) + " absolute error: " + str(abs(nlog - math.log(i))))
        else: 
            print("x: " + str(i) + " n: " + str((j+3)*5) + " naivelog(x): " + str(nlog) + " absolute error: " + str(abs(nlog - math.log(i))) + " relative error: " + str(abs((nlog - math.log(i))/math.log(i))))

print("")

# Here we compute the value of lnx for x = 1 to 14 using mylog. In each iteration of x
# we also compute the mylog for increasing values of n to show how n affects the error
print("MYLOG")
#loop over values of x
for i in range(1,15):
    print("")
    #loop over values of n
    for j in range(0, 5):
        mlog = mylog(i, (j+3)*5)
        if math.log(i) == 0:
            print("x: " + str(i) + " n: " + str((j+3)*5) + " mylog(x): " + str(mlog) + " absolute error: " + str(abs(mlog - math.log(i))))
        else:
            print("x: " + str(i) + " n: " + str((j+3)*5) + " mylog(x): " + str(mlog) + " absolute error: " + str(abs(mlog - math.log(i))) + " relative error: " + str(abs((mlog - math.log(i))/math.log(i))))
# Out:
# NAIVELOG
#
# 0.0
# x: 1 n: 15 naivelog(x): 0.0 absolute error: 0.0
# 0.0
# x: 1 n: 20 naivelog(x): 0.0 absolute error: 0.0
# 0.0
# x: 1 n: 25 naivelog(x): 0.0 absolute error: 0.0
# 0.0
# x: 1 n: 30 naivelog(x): 0.0 absolute error: 0.0
# 0.0
# x: 1 n: 35 naivelog(x): 0.0 absolute error: 0.0
#
# 2.115339696473484e-05
# x: 2 n: 15 naivelog(x): 0.6931545117404312 absolute error: 7.33118048590331e-06 relative error: 1.0576657730874648e-05
# 6.610368821213797e-07
# x: 2 n: 20 naivelog(x): 0.6931474097073078 absolute error: 2.29147362529325e-07 relative error: 3.3058976355384264e-07
# 2.065739601597727e-08
# x: 2 n: 25 naivelog(x): 0.6931471899151802 absolute error: 9.355234920072064e-09 relative error: 1.3496751025539225e-08
# 6.455436185603958e-10
# x: 2 n: 30 naivelog(x): 0.6931471824645996 absolute error: 1.904654323148236e-09 relative error: 2.747835346613685e-09
# 2.0173196446648944e-11
# x: 2 n: 35 naivelog(x): 0.693145751953125 absolute error: 1.4286068202862268e-06 relative error: 2.06104397500709e-06
#
# 3.3527548384260086e-05
# x: 3 n: 15 naivelog(x): 1.0986307054554345 absolute error: 1.8416787324726513e-05 relative error: 1.676368225141e-05
# 1.0477188723267972e-06
# x: 3 n: 20 naivelog(x): 1.0986128642689437 absolute error: 5.756008338853036e-07 relative error: 5.239344578815214e-07
# 3.274119819707266e-08
# x: 3 n: 25 naivelog(x): 1.0986123085021973 absolute error: 1.9834087483516782e-08 relative error: 1.805376445184535e-08
# 1.0231622216139158e-09
# x: 3 n: 30 naivelog(x): 1.0986120700836182 absolute error: 2.1858449161804572e-07 relative error: 1.9896417860303033e-07
# 3.1973756975389733e-11
# x: 3 n: 35 naivelog(x): 1.0986099243164062 absolute error: 2.3643517035321082e-06 relative error: 2.1521256660969114e-06
#
# 4.2307241395755923e-05
# x: 4 n: 15 naivelog(x): 1.38632368605613 absolute error: 2.9324936239527588e-05 relative error: 2.115347004357575e-05
# 1.3220742012265418e-06
# x: 4 n: 20 naivelog(x): 1.3862952776253223 absolute error: 9.165054317694654e-07 relative error: 6.61118920680803e-07
# 4.131479247604375e-08
# x: 4 n: 25 naivelog(x): 1.3862943947315216 absolute error: 3.3611631033991785e-08 relative error: 2.4245666704464766e-08
# 1.2910872371207915e-09
# x: 4 n: 30 naivelog(x): 1.3862943649291992 absolute error: 3.809308646296472e-09 relative error: 2.747835346613685e-09
# 4.034639289329789e-11
# x: 4 n: 35 naivelog(x): 1.38629150390625 absolute error: 2.8572136405724535e-06 relative error: 2.06104397500709e-06
#
# 4.911735344781398e-05
# x: 5 n: 15 naivelog(x): 1.6094774377779686 absolute error: 3.9525343868307417e-05 relative error: 2.4558476945860943e-05
# 1.5348807789195007e-06
# x: 5 n: 20 naivelog(x): 1.6094391476362944 absolute error: 1.2352021940831293e-06 relative error: 7.674742744285301e-07
# 4.7964988647564155e-08
# x: 5 n: 25 naivelog(x): 1.6094379499554634 absolute error: 3.7521363127623886e-08 relative error: 2.331333370348962e-08
# 1.498905666252881e-09
# x: 5 n: 30 naivelog(x): 1.6094377040863037 absolute error: 2.0834779657086244e-07 relative error: 1.2945376454799612e-07
# 4.6840753498145205e-11
# x: 5 n: 35 naivelog(x): 1.60943603515625 absolute error: 1.8772778502818e-06 relative error: 1.166418310255051e-06
#
# 5.4681654570565286e-05
# x: 6 n: 15 naivelog(x): 1.7918084569682833 absolute error: 4.898774022832342e-05 relative error: 2.7340578392159324e-05
# 1.7087564470052996e-06
# x: 6 n: 20 naivelog(x): 1.791761000175029 absolute error: 1.5309469740820703e-06 relative error: 8.544377749216803e-07
# 5.339859487918375e-08
# x: 6 n: 25 naivelog(x): 1.7917595207691193 absolute error: 5.1541064305382633e-08 relative error: 2.8765615692595227e-08
# 1.6687060622189165e-09
# x: 6 n: 30 naivelog(x): 1.7917594909667969 absolute error: 2.173874191768732e-08 relative error: 1.2132622872116333e-08
# 5.214695342203868e-11
# x: 6 n: 35 naivelog(x): 1.7917556762695312 absolute error: 3.7929585237073127e-06 relative error: 2.1168904581491823e-06
#
# 5.938622829027018e-05
# x: 7 n: 15 naivelog(x): 1.9459679286155733 absolute error: 5.777956026009612e-05 relative error: 2.969282024051652e-05
# 1.8557662531115682e-06
# x: 7 n: 20 naivelog(x): 1.9459119546227157 absolute error: 1.8055674024797241e-06 relative error: 9.278780951711867e-07
# 5.7992643132109833e-08
# x: 7 n: 25 naivelog(x): 1.9459102004766464 absolute error: 5.142133319147035e-08 relative error: 2.642533788953926e-08
# 1.8122698897116152e-09
# x: 7 n: 30 naivelog(x): 1.9459099769592285 absolute error: 1.720960847162445e-07 relative error: 8.843989266400224e-08
# 5.6633364664548935e-11
# x: 7 n: 35 naivelog(x): 1.9459075927734375 absolute error: 2.5562818757318695e-06 relative error: 1.3136690185684447e-06
#
# 6.346153330261117e-05
# x: 8 n: 15 naivelog(x): 2.079507523259963 absolute error: 6.598158012716127e-05 relative error: 3.173043281315778e-05
# 1.983111957093442e-06
# x: 8 n: 20 naivelog(x): 2.079443603521213 absolute error: 2.0618413771877897e-06 relative error: 9.915361099894983e-07
# 6.197218915815483e-08
# x: 8 n: 25 naivelog(x): 2.0794416069984436 absolute error: 6.531860785585764e-08 relative error: 3.1411610543805566e-08
# 1.9366308556811873e-09
# x: 8 n: 30 naivelog(x): 2.079441547393799 absolute error: 5.7139630804670105e-09 relative error: 2.7478354000041273e-09
# 6.051958933994683e-11
# x: 8 n: 35 naivelog(x): 2.079437255859375 absolute error: 4.285820460747658e-06 relative error: 2.0610439749536997e-06
#
# 6.705622086489171e-05
# x: 9 n: 15 naivelog(x): 2.1972982453007717 absolute error: 7.366796455210434e-05 relative error: 3.352773554054036e-05
# 2.0954388422200765e-06
# x: 9 n: 20 naivelog(x): 2.197226879419759 absolute error: 2.3020835393516847e-06 relative error: 1.0477233702449249e-06
# 6.548239728232375e-08
# x: 9 n: 25 naivelog(x): 2.197224646806717 absolute error: 6.947049735472888e-08 relative error: 3.161738589277508e-08
# 2.0463246652724365e-09
# x: 9 n: 30 naivelog(x): 2.1972243785858154 absolute error: 1.9875040413452894e-07 relative error: 9.04552070755925e-08
# 6.394751395077947e-11
# x: 9 n: 35 naivelog(x): 2.1972198486328125 absolute error: 4.7287034070642164e-06 relative error: 2.1521256660969114e-06
#
# 7.027178941143575e-05
# x: 10 n: 15 naivelog(x): 2.3026659954339266 absolute error: 8.090243988068124e-05 relative error: 3.5135483212689434e-05
# 2.1959186755626803e-06
# x: 10 n: 20 naivelog(x): 2.302587621146813 absolute error: 2.5281527671339177e-06 relative error: 1.0979627961746972e-06
# 6.862238555171984e-08
# x: 10 n: 25 naivelog(x): 2.302585169672966 absolute error: 7.667892010232435e-08 relative error: 3.330123187873979e-08
# 2.1444492848132768e-09
# x: 10 n: 30 naivelog(x): 2.3025848865509033 absolute error: 2.0644314258078111e-07 relative error: 8.965711764959947e-08
# 6.701394994479415e-11
# x: 10 n: 35 naivelog(x): 2.302581787109375 absolute error: 3.3058846709010936e-06 relative error: 1.4357274703808925e-06
#
# 7.31806338951646e-05
# x: 11 n: 15 naivelog(x): 2.3979830114767537 absolute error: 8.773867838307581e-05 relative error: 3.658987086649693e-05
# 2.2868137499187924e-06
# x: 11 n: 20 naivelog(x): 2.3978980146348476 absolute error: 2.741836476971571e-06 relative error: 1.1434346228856847e-06
# 7.14628505260606e-08
# x: 11 n: 25 naivelog(x): 2.397895358502865 absolute error: 8.570449416822612e-08 relative error: 3.574155015878071e-08
# 2.2332138360781073e-09
# x: 11 n: 30 naivelog(x): 2.397895097732544 absolute error: 1.7506582672410786e-07 relative error: 7.300812037541743e-08
# 6.978773114951764e-11
# x: 11 n: 35 naivelog(x): 2.39788818359375 absolute error: 7.08920462066942e-06 relative error: 2.956427956253585e-06
#
# 7.583620823803372e-05
# x: 12 n: 15 naivelog(x): 2.485000871543889 absolute error: 9.42217558885794e-05 relative error: 3.791762394640375e-05
# 2.3697944586675845e-06
# x: 12 n: 20 naivelog(x): 2.484909594291821 absolute error: 2.9445038207676077e-06 relative error: 1.1849555076923384e-06
# 7.405599178333944e-08
# x: 12 n: 25 naivelog(x): 2.484906740486622 absolute error: 9.069862150212771e-08 relative error: 3.6499810369079924e-08
# 2.3142496807793123e-09
# x: 12 n: 30 naivelog(x): 2.4849066734313965 absolute error: 2.3643396129813254e-08 relative error: 9.514802550763986e-09
# 7.232014986868762e-11
# x: 12 n: 35 naivelog(x): 2.4849014282226562 absolute error: 5.221565344104562e-06 relative error: 2.1013124756819493e-06
#
# 7.827910605229249e-05
# x: 13 n: 15 naivelog(x): 2.5650497471215203 absolute error: 0.00010038965998360183 relative error: 3.9139041748159447e-05
# 2.4461293168798193e-06
# x: 13 n: 20 naivelog(x): 2.5649524945765734 absolute error: 3.1371150366332756e-06 relative error: 1.2230709458287302e-06
# 7.644145050278439e-08
# x: 13 n: 25 naivelog(x): 2.5649494528770447 absolute error: 9.541550793912279e-08 relative error: 3.71997628965092e-08
# 2.3887951616785585e-09
# x: 13 n: 30 naivelog(x): 2.5649492740631104 absolute error: 8.339842638704908e-08 relative error: 3.251464834751604e-08
# 7.464984186356105e-11
# x: 13 n: 35 naivelog(x): 2.5649490356445312 absolute error: 3.218170054886116e-07 relative error: 1.2546719667288302e-07
#
# 8.054088147546601e-05
# x: 14 n: 15 naivelog(x): 2.63916360418807 absolute error: 0.00010627457281175978 relative error: 4.02698992625724e-05
# 2.5168043618073455e-06
# x: 14 n: 20 naivelog(x): 2.639060650486499 absolute error: 3.3208712406640473e-06 relative error: 1.2583550964950764e-06
# 7.865004048035473e-08
# x: 14 n: 25 naivelog(x): 2.63905743509531 absolute error: 1.0548005180410769e-07 relative error: 3.9968836834433365e-08
# 2.457813508272011e-09
# x: 14 n: 30 naivelog(x): 2.639057159423828 absolute error: 1.7019143028207395e-07 relative error: 6.448947825884697e-08
# 7.680656111119788e-11
# x: 14 n: 35 naivelog(x): 2.6390533447265625 absolute error: 3.984888695907074e-06 relative error: 1.509966703333429e-06
#
# MYLOG
#
# 0.0
# x: 1 n: 15 mylog(x): 0.0 absolute error: 0.0
# 0.0
# x: 1 n: 20 mylog(x): 0.0 absolute error: 0.0
# 0.0
# x: 1 n: 25 mylog(x): 0.0 absolute error: 0.0
# 0.0
# x: 1 n: 30 mylog(x): 0.0 absolute error: 0.0
# 0.0
# x: 1 n: 35 mylog(x): 0.0 absolute error: 0.0
#
# 2.11533969648081e-05
# x: 2 n: 15 mylog(x): 0.6931545117428318 absolute error: 7.3311828865385564e-06 relative error: 1.0576661194259212e-05
# 6.610368820742088e-07
# x: 2 n: 20 mylog(x): 0.6931474096578456 absolute error: 2.290979003172211e-07 relative error: 3.30518404665729e-07
# 2.0657395950533542e-08
# x: 2 n: 25 mylog(x): 0.6931471877192531 absolute error: 7.15930781325369e-09 relative error: 1.0328697878378709e-08
# 6.455436169949115e-10
# x: 2 n: 30 mylog(x): 0.6931471807836737 absolute error: 2.2372836916417782e-10 relative error: 3.2277180869933465e-10
# 2.0173238024783115e-11
# x: 2 n: 35 mylog(x): 0.6931471805669369 absolute error: 6.991629497576923e-12 relative error: 1.0086789203887223e-11
#
# 3.3527548384202e-05
# x: 3 n: 15 mylog(x): 1.0986307054535311 absolute error: 1.841678542136016e-05 relative error: 1.6763680518891284e-05
# 1.0477188722480995e-06
# x: 3 n: 20 mylog(x): 1.0986128641864232 absolute error: 5.755183134503739e-07 relative error: 5.2385934454465e-07
# 3.274119814196381e-08
# x: 3 n: 25 mylog(x): 1.098612306653051 absolute error: 1.7984941313997638e-08 relative error: 1.6370599072582266e-08
# 1.0231624257100179e-09
# x: 3 n: 30 mylog(x): 1.098612289230139 absolute error: 5.620293119790176e-10 relative error: 5.115811262773945e-10
# 3.1973825787592025e-11
# x: 3 n: 35 mylog(x): 1.0986122886856735 absolute error: 1.7563728249569976e-11 relative error: 1.598719441857251e-11
#
# 4.230724139581935e-05
# x: 4 n: 15 mylog(x): 1.3863236860582084 absolute error: 2.932493831786509e-05 relative error: 2.1153471542779354e-05
# 1.3220742011181771e-06
# x: 4 n: 20 mylog(x): 1.3862952775116937 absolute error: 9.163918031074303e-07 relative error: 6.610369549271926e-07
# 4.131479232779509e-08
# x: 4 n: 25 mylog(x): 1.386294389757122 absolute error: 2.8637231475059366e-08 relative error: 2.065739591692874e-08
# 1.2910872344065495e-09
# x: 4 n: 30 mylog(x): 1.386294362014804 absolute error: 8.949134766567113e-10 relative error: 6.455436173986693e-10
# 4.034647604997319e-11
# x: 4 n: 35 mylog(x): 1.3862943611478569 absolute error: 2.7966295945702768e-11 relative error: 2.0173418236449254e-11
#
# 4.911735344775213e-05
# x: 5 n: 15 mylog(x): 1.6094774377759418 absolute error: 3.952534184148426e-05 relative error: 2.4558475686524914e-05
# 1.5348807788671905e-06
# x: 5 n: 20 mylog(x): 1.6094391475814431 absolute error: 1.2351473428484638e-06 relative error: 7.674401934402287e-07
# 4.796498867966045e-08
# x: 5 n: 25 mylog(x): 1.6094379510324364 absolute error: 3.8598336082884543e-08 relative error: 2.398249462416897e-08
# 1.4989058614152468e-09
# x: 5 n: 30 mylog(x): 1.6094379136402983 absolute error: 1.2061980303457176e-09 relative error: 7.494529742507892e-10
# 4.684080813521853e-11
# x: 5 n: 35 mylog(x): 1.6094379124717946 absolute error: 3.7694292132073315e-11 relative error: 2.3420780535152665e-11
#
# 5.468165457055033e-05
# x: 6 n: 15 mylog(x): 1.7918084569677932 absolute error: 4.8987739738270974e-05 relative error: 2.734057811865585e-05
# 1.7087564469031258e-06
# x: 6 n: 20 mylog(x): 1.791761000067892 absolute error: 1.5308398371161047e-06 relative error: 8.543779806424785e-07
# 5.339859476884526e-08
# x: 6 n: 25 mylog(x): 1.791759517066774 absolute error: 4.783871898617065e-08 relative error: 2.669929742678075e-08
# 1.6687060433654257e-09
# x: 6 n: 30 mylog(x): 1.7917594707230153 absolute error: 1.494960377712573e-09 relative error: 8.343532730744534e-10
# 5.2147063813020146e-11
# x: 6 n: 35 mylog(x): 1.7917594692747727 absolute error: 4.671774078701674e-11 relative error: 2.6073667581700672e-11
#
# 5.9386228290271334e-05
# x: 7 n: 15 mylog(x): 1.945967928615611 absolute error: 5.77795602978437e-05 relative error: 2.969282025991494e-05
# 1.8557662531203724e-06
# x: 7 n: 20 mylog(x): 1.9459119546319477 absolute error: 1.805576634428263e-06 relative error: 9.278828394542378e-07
# 5.799264328120798e-08
# x: 7 n: 25 mylog(x): 1.94591020547955 absolute error: 5.64242368383816e-08 relative error: 2.899632178072253e-08
# 1.812270051630746e-09
# x: 7 n: 30 mylog(x): 1.9459101508185714 absolute error: 1.763258206111118e-09 relative error: 9.061354692903637e-10
# 5.6633439063746975e-11
# x: 7 n: 35 mylog(x): 1.945910149110417 absolute error: 5.5103699381220395e-11 relative error: 2.831769977045022e-11
#
# 6.346153330249916e-05
# x: 8 n: 15 mylog(x): 2.0795075232562925 absolute error: 6.598157645676395e-05 relative error: 3.173043104806978e-05
# 1.9831119571321932e-06
# x: 8 n: 20 mylog(x): 2.0794436035618467 absolute error: 2.0618820109064018e-06 relative error: 9.915556506776099e-07
# 6.197218913178463e-08
# x: 8 n: 25 mylog(x): 2.0794416061136065 absolute error: 6.443377076337242e-08 relative error: 3.098609384869789e-08
# 1.9366308522349134e-09
# x: 8 n: 30 mylog(x): 2.0794415436933904 absolute error: 2.0135546563437856e-09 relative error: 9.683151057553537e-10
# 6.051971407557022e-11
# x: 8 n: 35 mylog(x): 2.0794415417427596 absolute error: 6.292388832207507e-11 relative error: 3.025999387856956e-11
#
# 6.705622086490466e-05
# x: 9 n: 15 mylog(x): 2.1972982453011958 absolute error: 7.366796497620953e-05 relative error: 3.352773573355895e-05
# 2.095438842211035e-06
# x: 9 n: 20 mylog(x): 2.197226879410278 absolute error: 2.3020740584911437e-06 relative error: 1.0477190553193417e-06
# 6.548239735591368e-08
# x: 9 n: 25 mylog(x): 2.1972246492759853 absolute error: 7.193976570007976e-08 relative error: 3.274119834727824e-08
# 2.046324852466897e-09
# x: 9 n: 30 mylog(x): 2.197224579584337 absolute error: 2.2481172479160705e-09 relative error: 1.023162252554789e-09
# 6.394765157620637e-11
# x: 9 n: 35 mylog(x): 2.1972245774064736 absolute error: 7.02540248198602e-11 relative error: 3.197398460972609e-11
#
# 7.027178941143552e-05
# x: 10 n: 15 mylog(x): 2.302665995433919 absolute error: 8.090243987313173e-05 relative error: 3.5135483209410725e-05
# 2.1959186755542027e-06
# x: 10 n: 20 mylog(x): 2.3025876211379237 absolute error: 2.528143877800204e-06 relative error: 1.0979589355861175e-06
# 6.862238562102572e-08
# x: 10 n: 25 mylog(x): 2.3025851719984853 absolute error: 7.900443943498203e-08 relative error: 3.431119209247236e-08
# 2.1444494793777668e-09
# x: 10 n: 30 mylog(x): 2.3025850954629337 absolute error: 2.468887760898042e-09 relative error: 1.0722243309964945e-09
# 6.701404616094655e-11
# x: 10 n: 35 mylog(x): 2.3025850930711984 absolute error: 7.715250660567108e-11 relative error: 3.350690788384713e-11
#
# 7.318063389515093e-05
# x: 11 n: 15 mylog(x): 2.3979830114763057 absolute error: 8.77386779349898e-05 relative error: 3.6589870679630544e-05
# 2.28681374985434e-06
# x: 11 n: 20 mylog(x): 2.3978980145672644 absolute error: 2.741768893699259e-06 relative error: 1.143406438472012e-06
# 7.146285052533699e-08
# x: 11 n: 25 mylog(x): 2.3978953584785843 absolute error: 8.568021359067757e-08 relative error: 3.5731424371460476e-08
# 2.233214001614484e-09
# x: 11 n: 30 mylog(x): 2.397895275475875 absolute error: 2.677504440384837e-09 relative error: 1.116606079822727e-09
# 6.97879374749621e-11
# x: 11 n: 35 mylog(x): 2.39789527288204 absolute error: 8.366951576022075e-11 relative error: 3.4892898246793524e-11
#
# 7.583620823810427e-05
# x: 12 n: 15 mylog(x): 2.485000871546201 absolute error: 9.422175820050782e-05 relative error: 3.791762487679219e-05
# 2.3697944585283696e-06
# x: 12 n: 20 mylog(x): 2.4849095941458437 absolute error: 2.9443578433152595e-06 relative error: 1.1848967620439413e-06
# 7.405599182245477e-08
# x: 12 n: 25 mylog(x): 2.4849067417991146 absolute error: 9.201111428325248e-08 relative error: 3.702799631974199e-08
# 2.314249661437562e-09
# x: 12 n: 30 mylog(x): 2.48490665266335 absolute error: 2.8753497360867186e-09 relative error: 1.1571258567528197e-09
# 7.23203018388553e-11
# x: 12 n: 35 mylog(x): 2.4849066498778574 absolute error: 8.985701072106167e-11 relative error: 3.616112127541202e-11
#
# 7.827910605234445e-05
# x: 13 n: 15 mylog(x): 2.565049747123223 absolute error: 0.00010038966168623986 relative error: 3.913904241196906e-05
# 2.4461293168632225e-06
# x: 13 n: 20 mylog(x): 2.5649524945591704 absolute error: 3.13709763366532e-06 relative error: 1.2230641609119423e-06
# 7.644145058082827e-08
# x: 13 n: 25 mylog(x): 2.564949455495763 absolute error: 9.803422607035372e-08 relative error: 3.822072579529431e-08
# 2.3887952422025695e-09
# x: 13 n: 30 mylog(x): 2.564949360525109 absolute error: 3.0635720627003593e-09 relative error: 1.1943986550020217e-09
# 7.464985123245501e-11
# x: 13 n: 35 mylog(x): 2.5649493575572766 absolute error: 9.573986048394545e-11 relative error: 3.7326218627059634e-11
#
# 8.054088147554075e-05
# x: 14 n: 15 mylog(x): 2.6391636041905193 absolute error: 0.00010627457526091177 relative error: 4.0269900190612864e-05
# 2.5168043619245215e-06
# x: 14 n: 20 mylog(x): 2.639060650609367 absolute error: 3.3209941086020933e-06 relative error: 1.2584016540050885e-06
# 7.865004042971859e-08
# x: 14 n: 25 mylog(x): 2.639057433396243 absolute error: 1.0378098469487895e-07 relative error: 3.932502091949966e-08
# 2.457813669795559e-09
# x: 14 n: 30 mylog(x): 2.639057332858417 absolute error: 3.2431586305392557e-09 relative error: 1.2289079870091597e-09
# 7.680667708967263e-11
# x: 14 n: 35 mylog(x): 2.639057329716611 absolute error: 1.0135270400724039e-10 relative error: 3.84048890753034e-11

# %% [markdown]
# As can be seen from the outputs of the naivelog and mylog for varying values of x and n, the values of absolute error for mylog is generally smaller than for naivelog. For example for x = 10 we have that:
#
# Naivelog:
#
# x: 10 n: 15 naivelog(x): 2.3026659954339266 absolute error: 8.090243988068124e-05 relative error: 3.5135483212689434e-05
# x: 10 n: 20 naivelog(x): 2.302587621146813 absolute error: 2.5281527671339177e-06 relative error: 1.0979627961746972e-06
# x: 10 n: 25 naivelog(x): 2.302585169672966 absolute error: 7.667892010232435e-08 relative error: 3.330123187873979e-08
# x: 10 n: 30 naivelog(x): 2.3025848865509033 absolute error: 2.0644314258078111e-07 relative error: 8.965711764959947e-08
# x: 10 n: 35 naivelog(x): 2.302581787109375 absolute error: 3.3058846709010936e-06 relative error: 1.4357274703808925e-06
#
# Mylog:
#
# x: 10 n: 15 mylog(x): 2.302665995433919 absolute error: 8.090243987313173e-05 relative error: 3.5135483209410725e-05
# x: 10 n: 20 mylog(x): 2.3025876211379237 absolute error: 2.528143877800204e-06 relative error: 1.0979589355861175e-06
# x: 10 n: 25 mylog(x): 2.3025851719984853 absolute error: 7.900443943498203e-08 relative error: 3.431119209247236e-08
# x: 10 n: 30 mylog(x): 2.3025850954629337 absolute error: 2.468887760898042e-09 relative error: 1.0722243309964945e-09
# x: 10 n: 35 mylog(x): 2.3025850930711984 absolute error: 7.715250660567108e-11 relative error: 3.350690788384713e-11
#
# As can be seen, though they are around the same for smaller values of n, as n increases, mylog has a much smaller error from the true value than naive log. This shows that mylog is capable of producing a much more accurate approximation of the true value.
# Additionally we can see that increasing the value of n decreases the error. This is for the reason that was explained above where the more we reduce the value of z, the smaller the truncated terms are in the Taylor Series for ln(1+x) and thus the smaller the error is by not including those terms in the approximation.
#
# The reason that naivelog behaves differently from my log is that the formula for z in naivelog includes a subtraction of 1 while the formula for z in mylog avoids any subtractions. This subtraction in naivelog can result in a loss of precision when sqrt(x) is very close to one due to cancellation of digits. As a result, this would lead to more error in the final computation of the natrual logarithm while in mylog no cancellation of digits occurs in computation of z. This is why as n increases, meaning that the iterative computation of sqrt x is much closer to zero, we see a lot more error in naivelog than in mylog.

# %%
import math

# For this algorithm, we use the fact that e^x = e^(nr) where n = 2^k
# this mean e^x = (e^r)^n and since r is small, we compute the value of e^r using the first two terms of the taylor series for e^x which are 1 and x
# so we get x^r = 1 + r and then we need to scale the value by taking (1+r) ^ n to get back the approximation of e^x 
def myexponential(x, n):
    r = x
    # Here we find the value of r by dividing by 2 n times such that r = x/2^n
    for i in range (n):
        r = r/2
    # we then add 1 to final r to get the approximation of e^r = 1 + r
    l = 1 + r
    #Finally need to scale back to get approximation of e^x by taking (1 + r)*(1 + r)*... n times
    for i in range (n):
        l = l * l
    return l

# For this algorithm we use the fact that sin (x) = 2sin(x/2)cos(x/2) = 2sin(x/2)* sqrt(1-sin^2(x/2))
# This mean that we only need to reduce the argument by two once since sin can be scaled between 0 an pi/2
def mysin(x, n):
    # Divide x by 2 since in equaion we use x/2 and also this will provide less error from truncation of terms
    # In the Taylor Series as x is smaller
    x = x/2

    # Now apply formula for sin assuming that sin r = r where x is the first term in the Taylor Series for sin
    result = 2 * x * math.sqrt(1 - x ** 2)
    return result

# For this algorithm we use the relationcos x = 2 * cos^2 (x/2) - 1
# This means that we only need to reduce the argument by two once since cos can be scaled between 0 an pi/2
def mycos(x, n):
    # Divide x by 2 since in equaion we use x/2 and also this will provide less error from truncation of terms
    # In the Taylor Series as x is smaller
    x = x/2

    # Now we apply the formula for cos assuming that cos r = 1 - r^2/2 which is the first two terms in the Taylor Series for cos
    # use first two terms instead of just one since first term is 1 and doesn't depend on x
    result = 2 * (1 - x**2/2) ** 2 -1
    return result
    

print("MYEXP")
# Approximate value of e^x for x = 1, ..., 15 and then show absolute and relative error
for i in range(1, 15):
    print()
    #loop over values of n
    for j in range(0, 5):
        x = i
        # Use powers of 2 for values of n since we get more better approximation for higher powers
        n = 2 ** j
        mexp = myexponential(x, n)
        print("x: " + str(x) + " n: " + str(n) + " myexp(x): " + str(mexp) + " absolute error: " + str(abs(mexp - math.exp(x))) + " relative error: " + str(abs((mexp - math.exp(x))/math.exp(x))))

print()
print("MYSIN")
# Approximate value of sin(x) for x = 0.1, ..., 1.6 and then show absolute and relative error
for i in range(0, 15):
    print()
    #loop over values of n
    for j in range(0, 5):
        # Divide by 10 so that values range from 0 to pi/2 and a bit over
        x = i/10
        n = (j+3)*5
        msin = mysin(x, n)
        if (math.sin(x) == 0):
            print("x: " + str(x) + " n: " + str(n) + " mysin(x): " + str(msin) + " absolute error: " + str(abs(msin - math.sin(x))))
        else: 
            print("x: " + str(x) + " n: " + str(n) + " mysin(x): " + str(msin) + " absolute error: " + str(abs(msin - math.sin(x))) + " relative error: " + str(abs((msin - math.sin(x))/math.sin(x))))

print()
print("MYCOS")
# Approximate value of cos(x) for x = 0.1, ..., 1.6 and then show absolute and relative error
for i in range(1, 15):
    print()
    #loop over values of n
    for j in range(0, 5):
        # Divide by 10 so that values range from 0 to pi/2 and a bit over
        x = i/10
        n = (j+3)*5
        mcos = mycos(x, n)
        if (math.cos(x) == 0):
            print("x: " + str(x) + " n: " + str(n) + " mycos(x): " + str(mcos) + " absolute error: " + str(abs(mcos - math.cos(x))))
        else: 
            print("x: " + str(x) + " n: " + str(n) + " mycos(x): " + str(mcos) + " absolute error: " + str(abs(mcos - math.cos(x))) + " relative error: " + str(abs((mcos - math.cos(x))/math.cos(x))))
# Out:
# MYEXP
#
# x: 1 n: 1 myexp(x): 2.25 absolute error: 0.4682818284590451 relative error: 0.17227125736425472
# x: 1 n: 2 myexp(x): 2.44140625 absolute error: 0.2768755784590451 relative error: 0.10185683307753335
# x: 1 n: 4 myexp(x): 2.6379284973666 absolute error: 0.08035333109244513 relative error: 0.0295603385385526
# x: 1 n: 8 myexp(x): 2.712991624253442 absolute error: 0.005290204205603111 relative error: 0.0019461573668400863
# x: 1 n: 16 myexp(x): 2.71826108990388 absolute error: 2.0738555165156214e-05 relative error: 7.629288084860797e-06
#
# x: 2 n: 1 myexp(x): 4.0 absolute error: 3.3890560989306504 relative error: 0.45865886705354925
# x: 2 n: 2 myexp(x): 5.0625 absolute error: 2.3265560989306504 relative error: 0.31486512861464827
# x: 2 n: 4 myexp(x): 6.583250172027423 absolute error: 0.8058059269032274 relative error: 0.10905397335118949
# x: 2 n: 8 myexp(x): 7.331850598741038 absolute error: 0.057205500189612124 relative error: 0.007741922570853258
# x: 2 n: 16 myexp(x): 7.388830610860716 absolute error: 0.00022548806993416548 relative error: 3.0516491811017415e-05
#
# x: 3 n: 1 myexp(x): 6.25 absolute error: 13.835536923187668 relative error: 0.6888308227008504
# x: 3 n: 2 myexp(x): 9.37890625 absolute error: 10.706630673187668 relative error: 0.5330517533154636
# x: 3 n: 4 myexp(x): 15.636440361240236 absolute error: 4.449096561947432 relative error: 0.2215074747049052
# x: 3 n: 8 myexp(x): 19.738242711069635 absolute error: 0.34729421211803313 relative error: 0.017290760682483957
# x: 3 n: 16 myexp(x): 20.084157848229847 absolute error: 0.0013790749578213024 relative error: 6.866009920945827e-05
#
# x: 4 n: 1 myexp(x): 9.0 absolute error: 45.598150033144236 relative error: 0.8351592500013924
# x: 4 n: 2 myexp(x): 16.0 absolute error: 38.598150033144236 relative error: 0.7069497777802531
# x: 4 n: 4 myexp(x): 35.52713678800501 absolute error: 19.071013245139227 relative error: 0.3492977918402367
# x: 4 n: 8 myexp(x): 52.93537093864136 absolute error: 1.6627790945028735 relative error: 0.03045486144665104
# x: 4 n: 16 myexp(x): 54.591485897799245 absolute error: 0.006664135344990996 relative error: 0.00012205789648450507
#
# x: 5 n: 1 myexp(x): 12.25 absolute error: 136.1631591025766 relative error: 0.917460149261203
# x: 5 n: 2 myexp(x): 25.62890625 absolute error: 122.7842528525766 relative error: 0.8273137880429697
# x: 5 n: 4 myexp(x): 77.55128409250516 absolute error: 70.86187501007144 relative error: 0.47746355807368035
# x: 5 n: 8 myexp(x): 141.42909383389556 absolute error: 6.984065268681036 relative error: 0.04705826161852642
# x: 5 n: 16 myexp(x): 148.38485567762822 absolute error: 0.028303424948376232 relative error: 0.00019070697719475238
#
# x: 6 n: 1 myexp(x): 16.0 absolute error: 387.4287934927351 relative error: 0.9603399651733383
# x: 6 n: 2 myexp(x): 39.0625 absolute error: 364.3662934927351 relative error: 0.9031737430989704
# x: 6 n: 4 myexp(x): 163.2462338235007 absolute error: 240.18255966923442 relative error: 0.5953530425774124
# x: 6 n: 8 myexp(x): 376.4432012903198 absolute error: 26.98559220241532 relative error: 0.06689059541036768
# x: 6 n: 16 myexp(x): 403.3180104412634 absolute error: 0.11078305147168521 relative error: 0.00027460372997318097
#
# x: 7 n: 1 myexp(x): 20.25 absolute error: 1076.3831584284585 relative error: 0.9815343901975211
# x: 7 n: 2 myexp(x): 57.19140625 absolute error: 1039.4417521784585 relative error: 0.9478481880559232
# x: 7 n: 4 myexp(x): 332.44947678442855 absolute error: 764.18368164403 relative error: 0.6968453176622448
# x: 7 n: 8 myexp(x): 998.2527000666585 absolute error: 98.38045836180004 relative error: 0.08971136574311246
# x: 7 n: 16 myexp(x): 1096.2232985267667 absolute error: 0.40985990169178876 relative error: 0.00037374385275668916
#
# x: 8 n: 1 myexp(x): 25.0 absolute error: 2955.9579870417283 relative error: 0.9916134343024372
# x: 8 n: 2 myexp(x): 81.0 absolute error: 2899.9579870417283 relative error: 0.9728275271398965
# x: 8 n: 4 myexp(x): 656.8408355712891 absolute error: 2324.1171514704392 relative error: 0.7796544471855738
# x: 8 n: 8 myexp(x): 2637.388807729838 absolute error: 343.56917931189037 relative error: 0.11525461975827604
# x: 8 n: 16 myexp(x): 2979.5029148358262 absolute error: 1.45507220590207 relative error: 0.00048812234597981317
#
# x: 9 n: 1 myexp(x): 30.25 absolute error: 8072.833927575384 relative error: 0.996266853426378
# x: 9 n: 2 myexp(x): 111.56640625 absolute error: 7991.517521325384 relative error: 0.9862316116620325
# x: 9 n: 4 myexp(x): 1262.177448353619 absolute error: 6840.906479221765 relative error: 0.8442349283760547
# x: 9 n: 8 myexp(x): 6942.447560190484 absolute error: 1160.6363673849 relative error: 0.14323390671484593
# x: 9 n: 16 myexp(x): 8098.07838112004 absolute error: 5.005546455344302 relative error: 0.0006177335074008135
#
# x: 10 n: 1 myexp(x): 36.0 absolute error: 21990.465794806718 relative error: 0.9983656025285506
# x: 10 n: 2 myexp(x): 150.0625 absolute error: 21876.403294806718 relative error: 0.9931871730400171
# x: 10 n: 4 myexp(x): 2364.0346895461303 absolute error: 19662.431105260588 relative error: 0.892672991138528
# x: 10 n: 8 myexp(x): 18208.235329376726 absolute error: 3818.2304654299915 relative error: 0.17334739494750145
# x: 10 n: 16 myexp(x): 22009.669051890964 absolute error: 16.796742915754294 relative error: 0.0007625709486137599
#
# x: 11 n: 1 myexp(x): 42.25 absolute error: 59831.89171519782 relative error: 0.9992943531416121
# x: 11 n: 2 myexp(x): 197.75390625 absolute error: 59676.38780894782 relative error: 0.9966971734277102
# x: 11 n: 4 myexp(x): 4324.147543769325 absolute error: 55549.994171428494 relative error: 0.9277793815510891
# x: 11 n: 8 myexp(x): 47582.99667510066 absolute error: 12291.145040097159 relative error: 0.20528302682921473
# x: 11 n: 16 myexp(x): 59818.900181458106 absolute error: 55.241533739710576 relative error: 0.0009226275677149064
#
# x: 12 n: 1 myexp(x): 49.0 absolute error: 162705.79141900392 relative error: 0.9996989335946869
# x: 12 n: 2 myexp(x): 256.0 absolute error: 162498.79141900392 relative error: 0.998427081637548
# x: 12 n: 4 myexp(x): 7737.644615024561 absolute error: 155017.14680397935 relative error: 0.9524582683707026
# x: 12 n: 8 myexp(x): 123901.38228493735 absolute error: 38853.40913406656 relative error: 0.23872359637044688
# x: 12 n: 16 myexp(x): 162576.10365090444 absolute error: 178.6877680994803 relative error: 0.0010978955921454733
#
# x: 13 n: 1 myexp(x): 56.25 absolute error: 442357.1420089205 relative error: 0.9998728564708573
# x: 13 n: 2 myexp(x): 326.25390625 absolute error: 442087.1381026705 relative error: 0.9992625587015607
# x: 13 n: 4 myexp(x): 13565.88852105346 absolute error: 428847.503487867 relative error: 0.9693366232440361
# x: 13 n: 8 myexp(x): 321478.96450692526 absolute error: 120934.42750199523 relative error: 0.2733516427991782
# x: 13 n: 16 myexp(x): 441843.4014003633 absolute error: 569.9906085571856 relative error: 0.0012883665342248336
#
# x: 14 n: 1 myexp(x): 64.0 absolute error: 1202540.2841647768 relative error: 0.9999467821619774
# x: 14 n: 2 myexp(x): 410.0625 absolute error: 1202194.2216647768 relative error: 0.9996590212546226
# x: 14 n: 4 myexp(x): 23335.674213288694 absolute error: 1179268.6099514882 relative error: 0.980595716712006
# x: 14 n: 8 myexp(x): 831175.0627522387 absolute error: 371429.2214125381 relative error: 0.3088540647188033
# x: 14 n: 16 myexp(x): 1200807.555814846 absolute error: 1796.7283499308396 relative error: 0.0014940312233950581
#
# MYSIN
#
# x: 0.0 n: 15 mysin(x): 0.0 absolute error: 0.0
# x: 0.0 n: 20 mysin(x): 0.0 absolute error: 0.0
# x: 0.0 n: 25 mysin(x): 0.0 absolute error: 0.0
# x: 0.0 n: 30 mysin(x): 0.0 absolute error: 0.0
# x: 0.0 n: 35 mysin(x): 0.0 absolute error: 0.0
#
# x: 0.1 n: 15 mysin(x): 0.0998749217771909 absolute error: 4.150513036274561e-05 relative error: 0.00041574386369620743
# x: 0.1 n: 20 mysin(x): 0.0998749217771909 absolute error: 4.150513036274561e-05 relative error: 0.00041574386369620743
# x: 0.1 n: 25 mysin(x): 0.0998749217771909 absolute error: 4.150513036274561e-05 relative error: 0.00041574386369620743
# x: 0.1 n: 30 mysin(x): 0.0998749217771909 absolute error: 4.150513036274561e-05 relative error: 0.00041574386369620743
# x: 0.1 n: 35 mysin(x): 0.0998749217771909 absolute error: 4.150513036274561e-05 relative error: 0.00041574386369620743
#
# x: 0.2 n: 15 mysin(x): 0.198997487421324 absolute error: 0.00032815662626278774 relative error: 0.001651772948293162
# x: 0.2 n: 20 mysin(x): 0.198997487421324 absolute error: 0.00032815662626278774 relative error: 0.001651772948293162
# x: 0.2 n: 25 mysin(x): 0.198997487421324 absolute error: 0.00032815662626278774 relative error: 0.001651772948293162
# x: 0.2 n: 30 mysin(x): 0.198997487421324 absolute error: 0.00032815662626278774 relative error: 0.001651772948293162
# x: 0.2 n: 35 mysin(x): 0.198997487421324 absolute error: 0.00032815662626278774 relative error: 0.001651772948293162
#
# x: 0.3 n: 15 mysin(x): 0.29660579899927786 absolute error: 0.0010855923379383126 relative error: 0.0036734961382264477
# x: 0.3 n: 20 mysin(x): 0.29660579899927786 absolute error: 0.0010855923379383126 relative error: 0.0036734961382264477
# x: 0.3 n: 25 mysin(x): 0.29660579899927786 absolute error: 0.0010855923379383126 relative error: 0.0036734961382264477
# x: 0.3 n: 30 mysin(x): 0.29660579899927786 absolute error: 0.0010855923379383126 relative error: 0.0036734961382264477
# x: 0.3 n: 35 mysin(x): 0.29660579899927786 absolute error: 0.0010855923379383126 relative error: 0.0036734961382264477
#
# x: 0.4 n: 15 mysin(x): 0.3919183588453085 absolute error: 0.0025000165366579896 relative error: 0.006419873603890215
# x: 0.4 n: 20 mysin(x): 0.3919183588453085 absolute error: 0.0025000165366579896 relative error: 0.006419873603890215
# x: 0.4 n: 25 mysin(x): 0.3919183588453085 absolute error: 0.0025000165366579896 relative error: 0.006419873603890215
# x: 0.4 n: 30 mysin(x): 0.3919183588453085 absolute error: 0.0025000165366579896 relative error: 0.006419873603890215
# x: 0.4 n: 35 mysin(x): 0.3919183588453085 absolute error: 0.0025000165366579896 relative error: 0.006419873603890215
#
# x: 0.5 n: 15 mysin(x): 0.4841229182759271 absolute error: 0.004697379671724122 relative error: 0.009797933763395352
# x: 0.5 n: 20 mysin(x): 0.4841229182759271 absolute error: 0.004697379671724122 relative error: 0.009797933763395352
# x: 0.5 n: 25 mysin(x): 0.4841229182759271 absolute error: 0.004697379671724122 relative error: 0.009797933763395352
# x: 0.5 n: 30 mysin(x): 0.4841229182759271 absolute error: 0.004697379671724122 relative error: 0.009797933763395352
# x: 0.5 n: 35 mysin(x): 0.4841229182759271 absolute error: 0.004697379671724122 relative error: 0.009797933763395352
#
# x: 0.6 n: 15 mysin(x): 0.5723635208501674 absolute error: 0.007721047455132024 relative error: 0.01367422363519264
# x: 0.6 n: 20 mysin(x): 0.5723635208501674 absolute error: 0.007721047455132024 relative error: 0.01367422363519264
# x: 0.6 n: 25 mysin(x): 0.5723635208501674 absolute error: 0.007721047455132024 relative error: 0.01367422363519264
# x: 0.6 n: 30 mysin(x): 0.5723635208501674 absolute error: 0.007721047455132024 relative error: 0.01367422363519264
# x: 0.6 n: 35 mysin(x): 0.5723635208501674 absolute error: 0.007721047455132024 relative error: 0.01367422363519264
#
# x: 0.7 n: 15 mysin(x): 0.6557247898318318 absolute error: 0.011507102594140783 relative error: 0.017862133906135853
# x: 0.7 n: 20 mysin(x): 0.6557247898318318 absolute error: 0.011507102594140783 relative error: 0.017862133906135853
# x: 0.7 n: 25 mysin(x): 0.6557247898318318 absolute error: 0.011507102594140783 relative error: 0.017862133906135853
# x: 0.7 n: 30 mysin(x): 0.6557247898318318 absolute error: 0.011507102594140783 relative error: 0.017862133906135853
# x: 0.7 n: 35 mysin(x): 0.6557247898318318 absolute error: 0.011507102594140783 relative error: 0.017862133906135853
#
# x: 0.8 n: 15 mysin(x): 0.7332121111929344 absolute error: 0.0158560202934116 relative error: 0.022103416273400664
# x: 0.8 n: 20 mysin(x): 0.7332121111929344 absolute error: 0.0158560202934116 relative error: 0.022103416273400664
# x: 0.8 n: 25 mysin(x): 0.7332121111929344 absolute error: 0.0158560202934116 relative error: 0.022103416273400664
# x: 0.8 n: 30 mysin(x): 0.7332121111929344 absolute error: 0.0158560202934116 relative error: 0.022103416273400664
# x: 0.8 n: 35 mysin(x): 0.7332121111929344 absolute error: 0.0158560202934116 relative error: 0.022103416273400664
#
# x: 0.9 n: 15 mysin(x): 0.8037256994771288 absolute error: 0.020398789849645493 relative error: 0.026041221869099688
# x: 0.9 n: 20 mysin(x): 0.8037256994771288 absolute error: 0.020398789849645493 relative error: 0.026041221869099688
# x: 0.9 n: 25 mysin(x): 0.8037256994771288 absolute error: 0.020398789849645493 relative error: 0.026041221869099688
# x: 0.9 n: 30 mysin(x): 0.8037256994771288 absolute error: 0.020398789849645493 relative error: 0.026041221869099688
# x: 0.9 n: 35 mysin(x): 0.8037256994771288 absolute error: 0.020398789849645493 relative error: 0.026041221869099688
#
# x: 1.0 n: 15 mysin(x): 0.8660254037844386 absolute error: 0.02455441897654209 relative error: 0.029180351336948046
# x: 1.0 n: 20 mysin(x): 0.8660254037844386 absolute error: 0.02455441897654209 relative error: 0.029180351336948046
# x: 1.0 n: 25 mysin(x): 0.8660254037844386 absolute error: 0.02455441897654209 relative error: 0.029180351336948046
# x: 1.0 n: 30 mysin(x): 0.8660254037844386 absolute error: 0.02455441897654209 relative error: 0.029180351336948046
# x: 1.0 n: 35 mysin(x): 0.8660254037844386 absolute error: 0.02455441897654209 relative error: 0.029180351336948046
#
# x: 1.1 n: 15 mysin(x): 0.9186811198669537 absolute error: 0.02747375980551825 relative error: 0.030827572837397062
# x: 1.1 n: 20 mysin(x): 0.9186811198669537 absolute error: 0.02747375980551825 relative error: 0.030827572837397062
# x: 1.1 n: 25 mysin(x): 0.9186811198669537 absolute error: 0.02747375980551825 relative error: 0.030827572837397062
# x: 1.1 n: 30 mysin(x): 0.9186811198669537 absolute error: 0.02747375980551825 relative error: 0.030827572837397062
# x: 1.1 n: 35 mysin(x): 0.9186811198669537 absolute error: 0.02747375980551825 relative error: 0.030827572837397062
#
# x: 1.2 n: 15 mysin(x): 0.96 absolute error: 0.027960914032773676 relative error: 0.02999972260150137
# x: 1.2 n: 20 mysin(x): 0.96 absolute error: 0.027960914032773676 relative error: 0.02999972260150137
# x: 1.2 n: 25 mysin(x): 0.96 absolute error: 0.027960914032773676 relative error: 0.02999972260150137
# x: 1.2 n: 30 mysin(x): 0.96 absolute error: 0.027960914032773676 relative error: 0.02999972260150137
# x: 1.2 n: 35 mysin(x): 0.96 absolute error: 0.027960914032773676 relative error: 0.02999972260150137
#
# x: 1.3 n: 15 mysin(x): 0.9879144699820931 absolute error: 0.024356284564900132 relative error: 0.02527744035961312
# x: 1.3 n: 20 mysin(x): 0.9879144699820931 absolute error: 0.024356284564900132 relative error: 0.02527744035961312
# x: 1.3 n: 25 mysin(x): 0.9879144699820931 absolute error: 0.024356284564900132 relative error: 0.02527744035961312
# x: 1.3 n: 30 mysin(x): 0.9879144699820931 absolute error: 0.024356284564900132 relative error: 0.02527744035961312
# x: 1.3 n: 35 mysin(x): 0.9879144699820931 absolute error: 0.024356284564900132 relative error: 0.02527744035961312
#
# x: 1.4 n: 15 mysin(x): 0.9997999799959989 absolute error: 0.014350250007538756 relative error: 0.01456213297425816
# x: 1.4 n: 20 mysin(x): 0.9997999799959989 absolute error: 0.014350250007538756 relative error: 0.01456213297425816
# x: 1.4 n: 25 mysin(x): 0.9997999799959989 absolute error: 0.014350250007538756 relative error: 0.01456213297425816
# x: 1.4 n: 30 mysin(x): 0.9997999799959989 absolute error: 0.014350250007538756 relative error: 0.01456213297425816
# x: 1.4 n: 35 mysin(x): 0.9997999799959989 absolute error: 0.014350250007538756 relative error: 0.01456213297425816
#
# MYCOS
#
# x: 0.1 n: 15 mycos(x): 0.9950031250000002 absolute error: 1.0402780254992194e-06 relative error: 1.0455011765790379e-06
# x: 0.1 n: 20 mycos(x): 0.9950031250000002 absolute error: 1.0402780254992194e-06 relative error: 1.0455011765790379e-06
# x: 0.1 n: 25 mycos(x): 0.9950031250000002 absolute error: 1.0402780254992194e-06 relative error: 1.0455011765790379e-06
# x: 0.1 n: 30 mycos(x): 0.9950031250000002 absolute error: 1.0402780254992194e-06 relative error: 1.0455011765790379e-06
# x: 0.1 n: 35 mycos(x): 0.9950031250000002 absolute error: 1.0402780254992194e-06 relative error: 1.0455011765790379e-06
#
# x: 0.2 n: 15 mycos(x): 0.9800500000000001 absolute error: 1.6577841241538493e-05 relative error: 1.6915015384009855e-05
# x: 0.2 n: 20 mycos(x): 0.9800500000000001 absolute error: 1.6577841241538493e-05 relative error: 1.6915015384009855e-05
# x: 0.2 n: 25 mycos(x): 0.9800500000000001 absolute error: 1.6577841241538493e-05 relative error: 1.6915015384009855e-05
# x: 0.2 n: 30 mycos(x): 0.9800500000000001 absolute error: 1.6577841241538493e-05 relative error: 1.6915015384009855e-05
# x: 0.2 n: 35 mycos(x): 0.9800500000000001 absolute error: 1.6577841241538493e-05 relative error: 1.6915015384009855e-05
#
# x: 0.3 n: 15 mycos(x): 0.955253125 absolute error: 8.336412560594475e-05 relative error: 8.72615319888448e-05
# x: 0.3 n: 20 mycos(x): 0.955253125 absolute error: 8.336412560594475e-05 relative error: 8.72615319888448e-05
# x: 0.3 n: 25 mycos(x): 0.955253125 absolute error: 8.336412560594475e-05 relative error: 8.72615319888448e-05
# x: 0.3 n: 30 mycos(x): 0.955253125 absolute error: 8.336412560594475e-05 relative error: 8.72615319888448e-05
# x: 0.3 n: 35 mycos(x): 0.955253125 absolute error: 8.336412560594475e-05 relative error: 8.72615319888448e-05
#
# x: 0.4 n: 15 mycos(x): 0.9207999999999998 absolute error: 0.000260994002885262 relative error: 0.0002833623447139967
# x: 0.4 n: 20 mycos(x): 0.9207999999999998 absolute error: 0.000260994002885262 relative error: 0.0002833623447139967
# x: 0.4 n: 25 mycos(x): 0.9207999999999998 absolute error: 0.000260994002885262 relative error: 0.0002833623447139967
# x: 0.4 n: 30 mycos(x): 0.9207999999999998 absolute error: 0.000260994002885262 relative error: 0.0002833623447139967
# x: 0.4 n: 35 mycos(x): 0.9207999999999998 absolute error: 0.000260994002885262 relative error: 0.0002833623447139967
#
# x: 0.5 n: 15 mycos(x): 0.876953125 absolute error: 0.0006294368903727587 relative error: 0.0007172395142138065
# x: 0.5 n: 20 mycos(x): 0.876953125 absolute error: 0.0006294368903727587 relative error: 0.0007172395142138065
# x: 0.5 n: 25 mycos(x): 0.876953125 absolute error: 0.0006294368903727587 relative error: 0.0007172395142138065
# x: 0.5 n: 30 mycos(x): 0.876953125 absolute error: 0.0006294368903727587 relative error: 0.0007172395142138065
# x: 0.5 n: 35 mycos(x): 0.876953125 absolute error: 0.0006294368903727587 relative error: 0.0007172395142138065
#
# x: 0.6 n: 15 mycos(x): 0.82405 absolute error: 0.0012856149096783787 relative error: 0.0015576874261255182
# x: 0.6 n: 20 mycos(x): 0.82405 absolute error: 0.0012856149096783787 relative error: 0.0015576874261255182
# x: 0.6 n: 25 mycos(x): 0.82405 absolute error: 0.0012856149096783787 relative error: 0.0015576874261255182
# x: 0.6 n: 30 mycos(x): 0.82405 absolute error: 0.0012856149096783787 relative error: 0.0015576874261255182
# x: 0.6 n: 35 mycos(x): 0.82405 absolute error: 0.0012856149096783787 relative error: 0.0015576874261255182
#
# x: 0.7 n: 15 mycos(x): 0.7625031249999998 absolute error: 0.0023390622844886577 relative error: 0.0030582286429483093
# x: 0.7 n: 20 mycos(x): 0.7625031249999998 absolute error: 0.0023390622844886577 relative error: 0.0030582286429483093
# x: 0.7 n: 25 mycos(x): 0.7625031249999998 absolute error: 0.0023390622844886577 relative error: 0.0030582286429483093
# x: 0.7 n: 30 mycos(x): 0.7625031249999998 absolute error: 0.0023390622844886577 relative error: 0.0030582286429483093
# x: 0.7 n: 35 mycos(x): 0.7625031249999998 absolute error: 0.0023390622844886577 relative error: 0.0030582286429483093
#
# x: 0.8 n: 15 mycos(x): 0.6927999999999996 absolute error: 0.00390670934716586 relative error: 0.005607394467072896
# x: 0.8 n: 20 mycos(x): 0.6927999999999996 absolute error: 0.00390670934716586 relative error: 0.005607394467072896
# x: 0.8 n: 25 mycos(x): 0.6927999999999996 absolute error: 0.00390670934716586 relative error: 0.005607394467072896
# x: 0.8 n: 30 mycos(x): 0.6927999999999996 absolute error: 0.00390670934716586 relative error: 0.005607394467072896
# x: 0.8 n: 35 mycos(x): 0.6927999999999996 absolute error: 0.00390670934716586 relative error: 0.005607394467072896
#
# x: 0.9 n: 15 mycos(x): 0.6155031249999998 absolute error: 0.006106843270664686 relative error: 0.009824236389989187
# x: 0.9 n: 20 mycos(x): 0.6155031249999998 absolute error: 0.006106843270664686 relative error: 0.009824236389989187
# x: 0.9 n: 25 mycos(x): 0.6155031249999998 absolute error: 0.006106843270664686 relative error: 0.009824236389989187
# x: 0.9 n: 30 mycos(x): 0.6155031249999998 absolute error: 0.006106843270664686 relative error: 0.009824236389989187
# x: 0.9 n: 35 mycos(x): 0.6155031249999998 absolute error: 0.006106843270664686 relative error: 0.009824236389989187
#
# x: 1.0 n: 15 mycos(x): 0.53125 absolute error: 0.009052305868139765 relative error: 0.016754149982008353
# x: 1.0 n: 20 mycos(x): 0.53125 absolute error: 0.009052305868139765 relative error: 0.016754149982008353
# x: 1.0 n: 25 mycos(x): 0.53125 absolute error: 0.009052305868139765 relative error: 0.016754149982008353
# x: 1.0 n: 30 mycos(x): 0.53125 absolute error: 0.009052305868139765 relative error: 0.016754149982008353
# x: 1.0 n: 35 mycos(x): 0.53125 absolute error: 0.009052305868139765 relative error: 0.016754149982008353
#
# x: 1.1 n: 15 mycos(x): 0.4407531250000001 absolute error: 0.012842996425577236 relative error: 0.02831372628410893
# x: 1.1 n: 20 mycos(x): 0.4407531250000001 absolute error: 0.012842996425577236 relative error: 0.02831372628410893
# x: 1.1 n: 25 mycos(x): 0.4407531250000001 absolute error: 0.012842996425577236 relative error: 0.02831372628410893
# x: 1.1 n: 30 mycos(x): 0.4407531250000001 absolute error: 0.012842996425577236 relative error: 0.02831372628410893
# x: 1.1 n: 35 mycos(x): 0.4407531250000001 absolute error: 0.012842996425577236 relative error: 0.02831372628410893
#
# x: 1.2 n: 15 mycos(x): 0.3448000000000002 absolute error: 0.017557754476673404 relative error: 0.048454198260585765
# x: 1.2 n: 20 mycos(x): 0.3448000000000002 absolute error: 0.017557754476673404 relative error: 0.048454198260585765
# x: 1.2 n: 25 mycos(x): 0.3448000000000002 absolute error: 0.017557754476673404 relative error: 0.048454198260585765
# x: 1.2 n: 30 mycos(x): 0.3448000000000002 absolute error: 0.017557754476673404 relative error: 0.048454198260585765
# x: 1.2 n: 35 mycos(x): 0.3448000000000002 absolute error: 0.017557754476673404 relative error: 0.048454198260585765
#
# x: 1.3 n: 15 mycos(x): 0.24425312499999974 absolute error: 0.02324570362458761 relative error: 0.08690020716767716
# x: 1.3 n: 20 mycos(x): 0.24425312499999974 absolute error: 0.02324570362458761 relative error: 0.08690020716767716
# x: 1.3 n: 25 mycos(x): 0.24425312499999974 absolute error: 0.02324570362458761 relative error: 0.08690020716767716
# x: 1.3 n: 30 mycos(x): 0.24425312499999974 absolute error: 0.02324570362458761 relative error: 0.08690020716767716
# x: 1.3 n: 35 mycos(x): 0.24425312499999974 absolute error: 0.02324570362458761 relative error: 0.08690020716767716
#
# x: 1.4 n: 15 mycos(x): 0.14005 absolute error: 0.029917142900241 relative error: 0.17601721361993064
# x: 1.4 n: 20 mycos(x): 0.14005 absolute error: 0.029917142900241 relative error: 0.17601721361993064
# x: 1.4 n: 25 mycos(x): 0.14005 absolute error: 0.029917142900241 relative error: 0.17601721361993064
# x: 1.4 n: 30 mycos(x): 0.14005 absolute error: 0.029917142900241 relative error: 0.17601721361993064
# x: 1.4 n: 35 mycos(x): 0.14005 absolute error: 0.029917142900241 relative error: 0.17601721361993064

# %%
import math

#For argument reduction of arctan we use the following formula arctanx = 2arctan x/(1 + root(1 + x^2))
# This is derived from the following identity arctan a + arctan b = arctan (a+b)/(1-ab) where we set a = b
def myarctan(x, n):
    z = x
    # We use the value of z and iteratively compute z/(1 + root(1 + z^2)) n times
    for i in range(n):
        z = z/(1+math.sqrt(1+(z**2)))
    # Here we set l to z after the argument has been reduced n times where l represents the first term in the taylor series for arctan
    # The taylor series is arctan(x) = x - x^3/3 + x^5/5 - ... so we take arctan(z) = z assuming z is small
    l = z
    # Now we have to scale our reduction back from arctan(z) so that we get the approximate value of arctan(x)
    # We multiplyt l by 2 n times since we reduced x n times
    for i in range(n):
        l = l*2
    return l

# Here we compute arctan(x) for x=1 to 16 and different values on n. We show the absolute error in comparison to the exact value
# Can see from the results that larger values of n result in much smaller error
for i in range(1, 16):
    print("")
    #loop over values of n
    for j in range(0, 5):
        x = i/10
        n = (j+3)*5
        marctan = myarctan(x, n)
        print("x: " + str(x) + " n: " + str(n) + " myarctan(x): " + str(marctan) + " absolute error: " + str(abs(marctan - math.atan(x))) + " relative error: " + str(abs((marctan - math.atan(x))/math.atan(x))))


# Now to compute pi we know that arctan x = arctan y = arctan (x+y)/(1-xy)
# We know that pi/4 = arctan 1 from the triangle, and thus can use the algorithm to try and compute pi

print("")
pi = 4 * myarctan(1, 100)
print("PI: " + str(pi))

# We can see from the result below that we were able to estimate 15 digits of pi with a large value of n
# Out:
# x: 0.1 n: 15 myarctan(x): 0.09966865249146935 absolute error: 3.0730973321624333e-13 relative error: 3.083313815680347e-12
# x: 0.1 n: 20 myarctan(x): 0.09966865249116233 absolute error: 2.914335439641036e-16 relative error: 2.9240241207228725e-15
# x: 0.1 n: 25 myarctan(x): 0.09966865249116207 absolute error: 2.7755575615628914e-17 relative error: 2.784784876878926e-16
# x: 0.1 n: 30 myarctan(x): 0.09966865249116207 absolute error: 2.7755575615628914e-17 relative error: 2.784784876878926e-16
# x: 0.1 n: 35 myarctan(x): 0.09966865249116207 absolute error: 2.7755575615628914e-17 relative error: 2.784784876878926e-16
#
# x: 0.2 n: 15 myarctan(x): 0.1973955598522685 absolute error: 2.3877289034857085e-12 relative error: 1.2096163182705706e-11
# x: 0.2 n: 20 myarctan(x): 0.19739555984988302 absolute error: 2.248201624865942e-15 relative error: 1.1389322163962038e-14
# x: 0.2 n: 25 myarctan(x): 0.19739555984988075 absolute error: 2.7755575615628914e-17 relative error: 1.406089156044696e-16
# x: 0.2 n: 30 myarctan(x): 0.19739555984988075 absolute error: 2.7755575615628914e-17 relative error: 1.406089156044696e-16
# x: 0.2 n: 35 myarctan(x): 0.19739555984988075 absolute error: 2.7755575615628914e-17 relative error: 1.406089156044696e-16
#
# x: 0.3 n: 15 myarctan(x): 0.29145679448555306 absolute error: 7.685962977177496e-12 relative error: 2.6370848519577608e-11
# x: 0.3 n: 20 myarctan(x): 0.2914567944778745 absolute error: 7.382983113757291e-15 relative error: 2.5331312405955753e-14
# x: 0.3 n: 25 myarctan(x): 0.291456794477867 absolute error: 1.1102230246251565e-16 relative error: 3.809219910670038e-16
# x: 0.3 n: 30 myarctan(x): 0.291456794477867 absolute error: 1.1102230246251565e-16 relative error: 3.809219910670038e-16
# x: 0.3 n: 35 myarctan(x): 0.291456794477867 absolute error: 1.1102230246251565e-16 relative error: 3.809219910670038e-16
#
# x: 0.4 n: 15 myarctan(x): 0.3805063771294675 absolute error: 1.7102597116291918e-11 relative error: 4.49469395127679e-11
# x: 0.4 n: 20 myarctan(x): 0.3805063771123816 absolute error: 1.6708856520608606e-14 relative error: 4.3912158969347366e-14
# x: 0.4 n: 25 myarctan(x): 0.38050637711236507 absolute error: 1.6653345369377348e-16 relative error: 4.3766271398020633e-16
# x: 0.4 n: 30 myarctan(x): 0.38050637711236507 absolute error: 1.6653345369377348e-16 relative error: 4.3766271398020633e-16
# x: 0.4 n: 35 myarctan(x): 0.38050637711236507 absolute error: 1.6653345369377348e-16 relative error: 4.3766271398020633e-16
#
# x: 0.5 n: 15 myarctan(x): 0.46364760903174795 absolute error: 3.094180467400065e-11 relative error: 6.67356071148139e-11
# x: 0.5 n: 20 myarctan(x): 0.4636476090008367 absolute error: 3.0531133177191805e-14 relative error: 6.584986654625177e-14
# x: 0.5 n: 25 myarctan(x): 0.46364760900080654 absolute error: 3.885780586188048e-16 relative error: 8.380892105886589e-16
# x: 0.5 n: 30 myarctan(x): 0.46364760900080654 absolute error: 3.885780586188048e-16 relative error: 8.380892105886589e-16
# x: 0.5 n: 35 myarctan(x): 0.46364760900080654 absolute error: 3.885780586188048e-16 relative error: 8.380892105886589e-16
#
# x: 0.6 n: 15 myarctan(x): 0.5404195003195813 absolute error: 4.8997139678874646e-11 relative error: 9.06650105230143e-11
# x: 0.6 n: 20 myarctan(x): 0.5404195002706319 absolute error: 4.773959005888173e-14 relative error: 8.833802265643424e-14
# x: 0.6 n: 25 myarctan(x): 0.5404195002705845 absolute error: 3.3306690738754696e-16 relative error: 6.163117859751225e-16
# x: 0.6 n: 30 myarctan(x): 0.5404195002705845 absolute error: 3.3306690738754696e-16 relative error: 6.163117859751225e-16
# x: 0.6 n: 35 myarctan(x): 0.5404195002705845 absolute error: 3.3306690738754696e-16 relative error: 6.163117859751225e-16
#
# x: 0.7 n: 15 myarctan(x): 0.6107259644599247 absolute error: 7.07160996427092e-11 relative error: 1.1579022960556929e-10
# x: 0.7 n: 20 myarctan(x): 0.6107259643892777 absolute error: 6.916689443414725e-14 relative error: 1.1325356783106734e-13
# x: 0.7 n: 25 myarctan(x): 0.6107259643892087 absolute error: 1.1102230246251565e-16 relative error: 1.817874283002686e-16
# x: 0.7 n: 30 myarctan(x): 0.6107259643892087 absolute error: 1.1102230246251565e-16 relative error: 1.817874283002686e-16
# x: 0.7 n: 35 myarctan(x): 0.6107259643892087 absolute error: 1.1102230246251565e-16 relative error: 1.817874283002686e-16
#
# x: 0.8 n: 15 myarctan(x): 0.6747409423189178 absolute error: 9.5365049190832e-11 relative error: 1.4133579752336415e-10
# x: 0.8 n: 20 myarctan(x): 0.674740942223646 absolute error: 9.325873406851315e-14 relative error: 1.3821413261389881e-13
# x: 0.8 n: 25 myarctan(x): 0.6747409422235531 absolute error: 3.3306690738754696e-16 relative error: 4.936219021924957e-16
# x: 0.8 n: 30 myarctan(x): 0.6747409422235531 absolute error: 3.3306690738754696e-16 relative error: 4.936219021924957e-16
# x: 0.8 n: 35 myarctan(x): 0.6747409422235531 absolute error: 3.3306690738754696e-16 relative error: 4.936219021924957e-16
#
# x: 0.9 n: 15 myarctan(x): 0.7328151019086758 absolute error: 1.2216916367435715e-10 relative error: 1.6671212612366315e-10
# x: 0.9 n: 20 myarctan(x): 0.7328151017866259 absolute error: 1.192379528447418e-13 relative error: 1.627121937771962e-13
# x: 0.9 n: 25 myarctan(x): 0.7328151017865068 absolute error: 1.1102230246251565e-16 relative error: 1.5150111152439123e-16
# x: 0.9 n: 30 myarctan(x): 0.7328151017865068 absolute error: 1.1102230246251565e-16 relative error: 1.5150111152439123e-16
# x: 0.9 n: 35 myarctan(x): 0.7328151017865068 absolute error: 1.1102230246251565e-16 relative error: 1.5150111152439123e-16
#
# x: 1.0 n: 15 myarctan(x): 0.7853981635478487 absolute error: 1.5040046985603794e-10 relative error: 1.914958257674563e-10
# x: 1.0 n: 20 myarctan(x): 0.7853981633975956 absolute error: 1.4732659536775827e-13 relative error: 1.875820472134261e-13
# x: 1.0 n: 25 myarctan(x): 0.7853981633974487 absolute error: 4.440892098500626e-16 relative error: 5.654319433712919e-16
# x: 1.0 n: 30 myarctan(x): 0.7853981633974487 absolute error: 4.440892098500626e-16 relative error: 5.654319433712919e-16
# x: 1.0 n: 35 myarctan(x): 0.7853981633974487 absolute error: 4.440892098500626e-16 relative error: 5.654319433712919e-16
#
# x: 1.1 n: 15 myarctan(x): 0.8329812668538573 absolute error: 1.7942558550032572e-10 relative error: 2.15401705510928e-10
# x: 1.1 n: 20 myarctan(x): 0.8329812666746071 absolute error: 1.7541523789077473e-13 relative error: 2.1058725437019373e-13
# x: 1.1 n: 25 myarctan(x): 0.8329812666744324 absolute error: 6.661338147750939e-16 relative error: 7.996984343171914e-16
# x: 1.1 n: 30 myarctan(x): 0.8329812666744324 absolute error: 6.661338147750939e-16 relative error: 7.996984343171914e-16
# x: 1.1 n: 35 myarctan(x): 0.8329812666744324 absolute error: 6.661338147750939e-16 relative error: 7.996984343171914e-16
#
# x: 1.2 n: 15 myarctan(x): 0.8760580508069199 absolute error: 2.087264805439304e-10 relative error: 2.3825644933164754e-10
# x: 1.2 n: 20 myarctan(x): 0.8760580505983973 absolute error: 2.0383694732117874e-13 relative error: 2.3267516026134796e-13
# x: 1.2 n: 25 myarctan(x): 0.8760580505981939 absolute error: 4.440892098500626e-16 relative error: 5.069175604822396e-16
# x: 1.2 n: 30 myarctan(x): 0.8760580505981939 absolute error: 4.440892098500626e-16 relative error: 5.069175604822396e-16
# x: 1.2 n: 35 myarctan(x): 0.8760580505981939 absolute error: 4.440892098500626e-16 relative error: 5.069175604822396e-16
#
# x: 1.3 n: 15 myarctan(x): 0.9151007007912554 absolute error: 2.378949259806973e-10 relative error: 2.599658440178687e-10
# x: 1.3 n: 20 myarctan(x): 0.9151007005535928 absolute error: 2.3236967905404526e-13 relative error: 2.539279872843847e-13
# x: 1.3 n: 25 myarctan(x): 0.9151007005533606 absolute error: 1.1102230246251565e-16 relative error: 1.2132249750806722e-16
# x: 1.3 n: 30 myarctan(x): 0.9151007005533606 absolute error: 1.1102230246251565e-16 relative error: 1.2132249750806722e-16
# x: 1.3 n: 35 myarctan(x): 0.9151007005533606 absolute error: 1.1102230246251565e-16 relative error: 1.2132249750806722e-16
#
# x: 1.4 n: 15 myarctan(x): 0.9505468410786994 absolute error: 2.666242782112249e-10 relative error: 2.804956755034201e-10
# x: 1.4 n: 20 myarctan(x): 0.9505468408123354 absolute error: 2.603472992745992e-13 relative error: 2.73892130399569e-13
# x: 1.4 n: 25 myarctan(x): 0.9505468408120753 absolute error: 2.220446049250313e-16 relative error: 2.3359669970112495e-16
# x: 1.4 n: 30 myarctan(x): 0.9505468408120751 absolute error: 0.0 relative error: 0.0
# x: 1.4 n: 35 myarctan(x): 0.9505468408120751 absolute error: 0.0 relative error: 0.0
#
# x: 1.5 n: 15 myarctan(x): 0.9827937235420195 absolute error: 2.9469049422914395e-10 relative error: 2.998497927473865e-10
# x: 1.5 n: 20 myarctan(x): 0.9827937232476172 absolute error: 2.881028748902281e-13 relative error: 2.931468405580409e-13
# x: 1.5 n: 25 myarctan(x): 0.9827937232473295 absolute error: 4.440892098500626e-16 relative error: 4.51864108759986e-16
# x: 1.5 n: 30 myarctan(x): 0.9827937232473293 absolute error: 2.220446049250313e-16 relative error: 2.25932054379993e-16
# x: 1.5 n: 35 myarctan(x): 0.9827937232473293 absolute error: 2.220446049250313e-16 relative error: 2.25932054379993e-16
#
# PI: 3.141592653589795
